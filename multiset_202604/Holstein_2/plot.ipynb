# %% [markdown]
# ### Plotting the result

# %%
import numpy as np

data = np.load("Holstein2.npz", allow_pickle=True)

print("keys:", data.files)
for key in data.files:
    print(f"\n===== {key} =====")
    print(data[key])
# Out:
# keys: ['mol list', 'temperature', 'time series', 'energy array', 'r square array', 'electron occupations array', 'reduced density matrices', 'coherent length array', 'rho trace array', 'purity array']
#
# ===== mol list =====
# ...
