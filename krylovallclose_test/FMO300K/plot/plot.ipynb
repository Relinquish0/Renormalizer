# %%
import numpy as np
import pandas as pd

# 加载 .npz 文件
data = np.load('../singleset/fmo_300k_64bd_strictkrylov.npz',allow_pickle=True)

# 'mol list', 'tempearture', 'total time', 'other info', 'r square array', 
# 'electron occupations array', 'phonon occupations array', 'k occupations array', 
# 'eph entropy', 'bond entropy', 'coherent length array', 'time series'
df = data['electron occupations array']

df = pd.DataFrame(df)
print(df)
df.to_excel('singleset_64bd_strictkrylov.xlsx', index=False)
# Out:
#                 0             1             2         3             4  \
# 0    6.855446e-20  7.050178e-20  6.481926e-20  1.000000  6.798175e-20
# 1    4.827144e-05  3.051176e-05  2.021291e-05  0.994726  5.082762e-03
# 2    2.006448e-04  1.127092e-04  8.434990e-05  0.979087  2.013754e-02
# 3    4.521804e-04  2.458052e-04  2.062190e-04  0.953641  4.459669e-02
# 4    7.941808e-04  4.286473e-04  4.066583e-04  0.919285  7.754772e-02
# ..            ...           ...           ...       ...           ...
# 247  7.520498e-02  2.952399e-02  1.983225e-01  0.279092  3.043315e-01
# 248  7.546714e-02  2.955184e-02  1.984561e-01  0.278970  3.040139e-01
# 249  7.573002e-02  2.958027e-02  1.985891e-01  0.278774  3.037686e-01
# 250  7.599366e-02  2.960923e-02  1.987208e-01  0.278515  3.035883e-01
# 251  7.625811e-02  2.963867e-02  1.988500e-01  0.278200  3.034647e-01
#
#                 5             6
# 0    6.728824e-20  6.928315e-20
# 1    1.864406e-05  7.352707e-05
# 2    7.777461e-05  2.998361e-04
# 3    1.813121e-04  6.765300e-04
# 4    3.369040e-04  1.200750e-03
# ..            ...           ...
# 247  7.316012e-02  4.036448e-02
# 248  7.316069e-02  4.038074e-02
# 249  7.316092e-02  4.039676e-02
# 250  7.316084e-02  4.041250e-02
# 251  7.316049e-02  4.042791e-02
#
# [252 rows x 7 columns]

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def plot_fmo_error():
    """
    以 singleset_256bd.xlsx 为 benchmark，
    计算其余三个文件的 Mean Absolute Error 并绘图。
    """

    # ============================================================
    # 1. 路径配置（只需修改此处）
    # ============================================================
    test_dir = "."   # ← 修改为你的文件夹路径，若在同目录则保持 "."

    benchmark_file = os.path.join(test_dir, "singleset_256bd.xlsx")

    # 需要对比的三个文件（按 bond dimension 从小到大排列）
    data_files = [
        # os.path.join(test_dir, "multiset_16bd_thermo.xlsx"),
        # os.path.join(test_dir, "multiset_16bd_ancilla.xlsx"),
        # os.path.join(test_dir, "multiset_16bd_imag_tdvp.xlsx"),
        # os.path.join(test_dir, "multiset_64bd.xlsx"),
        os.path.join(test_dir, "singleset_16bd.xlsx"),
        os.path.join(test_dir, "singleset_64bd.xlsx"),
        os.path.join(test_dir, "singleset_16bd_strictkrylov.xlsx"),
        os.path.join(test_dir, "singleset_64bd_strictkrylov.xlsx"),
        os.path.join(test_dir, "singleset_128bd.xlsx"),
        # os.path.join(test_dir, "multiset_64bd.xlsx"),
    ]

    # ============================================================
    # 2. 样式配置：(标签, 颜色, 线型, 线宽)
    # ============================================================
    styles = {
        # "multiset_16bd_thermo.xlsx":  ("multiset_thermo  ($\\chi'=16$)",  "#fc0000", "-",  2.5),
        # "multiset_16bd_ancilla.xlsx":  ("multiset_ancilla  ($\\chi'=16$)",  "#4d0000", "-",  2.5),
        # "multiset_16bd_imag_tdvp.xlsx":  ("multiset_without_ancilla  ($\\chi'=16$)",  "#4737fc", "-",  2.5),
        # "multiset_64bd.xlsx":  ("multiset  ($\\chi'=64$)",  "#1f77b4", "-",  2.5),
        "singleset_16bd.xlsx":  ("singleset  ($\\chi'=16$)",  "#4df01b", "-",  2.5),
        "singleset_16bd_strictkrylov.xlsx":  ("singleset_strictkrylov  ($\\chi'=16$)",  "#256b0f", "--",  2.5),
        "singleset_64bd.xlsx":  ("singleset  ($\\chi'=64$)",  "#38d1ec", "-",  2.5),
        "singleset_64bd_strictkrylov.xlsx":  ("singleset_strictkrylov  ($\\chi'=64$)",  "#1d6673", "--",  2.5),
        # "singleset_128bd.xlsx": ("singleset  ($\\chi'=128$)", "#ff7f0e", "--",  2.5),
    }

    # ============================================================
    # 3. 时间步长（单位：fs）
    #    dt = 每步原子单位数 × 0.024188843265 fs/a.u.
    #    根据实际步长修改 dt_au
    # ============================================================
    dt_au = 160                          # ← 按需修改
    dt    = dt_au * 0.024188843265       # fs

    # ============================================================
    # 4. 读取 benchmark
    # ============================================================
    if not os.path.exists(benchmark_file):
        raise FileNotFoundError(f"Benchmark 文件未找到: {benchmark_file}")

    df_bm = pd.read_excel(benchmark_file, header=None)
    n_col = df_bm.shape[1]              # 自动识别列数（FMO 通常为 7 个 site）
    y_bm  = df_bm.iloc[:, :n_col].to_numpy(dtype=float)
    x_bm  = np.arange(len(y_bm)) * dt

    print(f"Benchmark : singleset_256bd.xlsx")
    print(f"  行数={len(y_bm)}, 列数={n_col}, dt={dt:.4f} fs")
    print(f"  时间范围: 0 ~ {x_bm[-1]:.1f} fs\n")

    # ============================================================
    # 5. 绘图
    # ============================================================
    fig, ax = plt.subplots(figsize=(10, 6))

    for fpath in data_files:
        if not os.path.exists(fpath):
            print(f"  [跳过] 文件不存在: {fpath}")
            continue

        fname = os.path.basename(fpath)
        label, color, ls, lw = styles.get(fname, (fname, None, "-", 2.0))

        # 读取预测数据
        df_pred = pd.read_excel(fpath, header=None)
        y_pred  = df_pred.iloc[:, :n_col].to_numpy(dtype=float)
        x_pred  = np.arange(len(y_pred)) * dt

        # 将 benchmark 插值到预测时间轴上
        y_bm_interp = np.column_stack([
            np.interp(x_pred, x_bm, y_bm[:, i]) for i in range(n_col)
        ])

        # 计算 Mean Absolute Error（对所有 site 取平均）
        mae = np.mean(np.abs(y_pred - y_bm_interp), axis=1)

        ax.plot(x_pred, mae,
                label=label,
                color=color,
                linestyle=ls,
                linewidth=lw)

        print(f"  [已绘制] {label}")
        print(f"    时间范围: 0 ~ {x_pred[-1]:.1f} fs,  "
              f"最大MAE={mae.max():.4e},  均值MAE={mae.mean():.4e}")

    # ============================================================
    # 6. 坐标轴与标注
    # ============================================================
    ax.set_xlabel("Time (fs)", fontsize=16)
    ax.set_ylabel("Mean Absolute Error", fontsize=16)
    ax.set_title(
        "MAE vs. singleset-256bd Benchmark\n"
        "FMO Model, 300K",
        fontsize=16
    )
    ax.set_xlim(left=0)
    ax.set_ylim(bottom=0,top=0.1)
    ax.tick_params(labelsize=13)
    ax.legend(fontsize=13, framealpha=0.85, edgecolor="gray")
    ax.grid(True, alpha=0.35)

    plt.tight_layout()
    # plt.savefig("FMO_MAE_vs_256bd.png", dpi=150)
    # print("\n✅ 已保存: FMO_MAE_vs_256bd.png")
    plt.show()


plot_fmo_error()
# Out:
# Benchmark : singleset_256bd.xlsx
#   行数=252, 列数=7, dt=3.8702 fs
#   时间范围: 0 ~ 971.4 fs
#
#   [已绘制] singleset  ($\chi'=16$)
#     时间范围: 0 ~ 971.4 fs,  最大MAE=5.5839e-02,  均值MAE=2.9023e-02
#   [已绘制] singleset  ($\chi'=64$)
#     时间范围: 0 ~ 971.4 fs,  最大MAE=3.9855e-02,  均值MAE=1.9888e-02
#   [已绘制] singleset_strictkrylov  ($\chi'=16$)
#     时间范围: 0 ~ 971.4 fs,  最大MAE=5.6287e-02,  均值MAE=2.8126e-02
#   [已绘制] singleset_strictkrylov  ($\chi'=64$)
#     时间范围: 0 ~ 971.4 fs,  最大MAE=2.1381e-02,  均值MAE=1.0377e-02
#   [跳过] 文件不存在: ./singleset_128bd.xlsx

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def plot_fmo_error():
    """
    以 singleset_256bd.xlsx 为 benchmark，
    计算其余文件相对于 benchmark 的平均累计误差并绘图。
    """

    # ============================================================
    # 1. 路径配置（只需修改此处）
    # ============================================================
    test_dir = "."   # ← 修改为你的文件夹路径，若在同目录则保持 "."

    benchmark_file = os.path.join(test_dir, "singleset_256bd.xlsx")

    # 需要对比的三个文件（按 bond dimension 从小到大排列）
    data_files = [
        # os.path.join(test_dir, "multiset_16bd_thermo.xlsx"),
        # os.path.join(test_dir, "multiset_16bd_ancilla.xlsx"),
        # os.path.join(test_dir, "multiset_16bd_imag_tdvp.xlsx"),
        # os.path.join(test_dir, "multiset_64bd.xlsx"),
        os.path.join(test_dir, "singleset_16bd.xlsx"),
        os.path.join(test_dir, "singleset_64bd.xlsx"),
        os.path.join(test_dir, "singleset_16bd_strictkrylov.xlsx"),
        os.path.join(test_dir, "singleset_64bd_strictkrylov.xlsx"),
        os.path.join(test_dir, "singleset_128bd.xlsx"),
        # os.path.join(test_dir, "multiset_64bd.xlsx"),
    ]

    # ============================================================
    # 2. 样式配置：(标签, 颜色, 线型, 线宽)
    # ============================================================
    styles = {
        # "multiset_16bd_thermo.xlsx":  ("multiset_thermo  ($\\chi'=16$)",  "#fc0000", "-",  2.5),
        # "multiset_16bd_ancilla.xlsx":  ("multiset_ancilla  ($\\chi'=16$)",  "#4d0000", "-",  2.5),
        # "multiset_16bd_imag_tdvp.xlsx":  ("multiset_without_ancilla  ($\\chi'=16$)",  "#4737fc", "-",  2.5),
        # "multiset_64bd.xlsx":  ("multiset  ($\\chi'=64$)",  "#1f77b4", "-",  2.5),
        "singleset_16bd.xlsx":  ("singleset  ($\\chi'=16$)",  "#4df01b", "-",  2.5),
        "singleset_16bd_strictkrylov.xlsx":  ("singleset_strictkrylov  ($\\chi'=16$)",  "#256b0f", "--",  2.5),
        "singleset_64bd.xlsx":  ("singleset  ($\\chi'=64$)",  "#38d1ec", "-",  2.5),
        "singleset_64bd_strictkrylov.xlsx":  ("singleset_strictkrylov  ($\\chi'=64$)",  "#1d6673", "--",  2.5),
        # "singleset_128bd.xlsx": ("singleset  ($\\chi'=128$)", "#ff7f0e", "--",  2.5),
    }

    # ============================================================
    # 3. 时间步长（单位：fs）
    #    dt = 每步原子单位数 × 0.024188843265 fs/a.u.
    #    根据实际步长修改 dt_au
    # ============================================================
    dt_au = 160                          # ← 按需修改
    dt    = dt_au * 0.024188843265       # fs

    # ============================================================
    # 4. 读取 benchmark
    # ============================================================
    if not os.path.exists(benchmark_file):
        raise FileNotFoundError(f"Benchmark 文件未找到: {benchmark_file}")

    df_bm = pd.read_excel(benchmark_file, header=None)
    n_col = df_bm.shape[1]              # 自动识别列数（FMO 通常为 7 个 site）
    y_bm  = df_bm.iloc[:, :n_col].to_numpy(dtype=float)
    x_bm  = np.arange(len(y_bm)) * dt

    print(f"Benchmark : singleset_256bd.xlsx")
    print(f"  行数={len(y_bm)}, 列数={n_col}, dt={dt:.4f} fs")
    print(f"  时间范围: 0 ~ {x_bm[-1]:.1f} fs\n")

    # ============================================================
    # 5. 绘图
    # ============================================================
    fig, ax = plt.subplots(figsize=(10, 6))

    for fpath in data_files:
        if not os.path.exists(fpath):
            print(f"  [跳过] 文件不存在: {fpath}")
            continue

        fname = os.path.basename(fpath)
        label, color, ls, lw = styles.get(fname, (fname, None, "-", 2.0))

        # 读取预测数据
        df_pred = pd.read_excel(fpath, header=None)
        y_pred  = df_pred.iloc[:, :n_col].to_numpy(dtype=float)
        x_pred  = np.arange(len(y_pred)) * dt

        # 将 benchmark 插值到预测时间轴上
        y_bm_interp = np.column_stack([
            np.interp(x_pred, x_bm, y_bm[:, i]) for i in range(n_col)
        ])

        # 计算平均累计误差：sum_n integral_0^t |P_n - P_ref_n| dt' / (n_col * t)
        abs_err = np.abs(y_pred - y_bm_interp)
        cum_err = np.zeros(len(x_pred), dtype=float)
        if len(x_pred) > 1:
            dt_seg = np.diff(x_pred)
            seg_integral = 0.5 * (abs_err[1:] + abs_err[:-1]) * dt_seg[:, None]
            cumulative_integral = np.cumsum(seg_integral, axis=0)
            cum_err[1:] = np.sum(cumulative_integral, axis=1) / (n_col * x_pred[1:])

        ax.plot(x_pred, cum_err,
                label=label,
                color=color,
                linestyle=ls,
                linewidth=lw)

        print(f"  [已绘制] {label}")
        print(f"    时间范围: 0 ~ {x_pred[-1]:.1f} fs,  "
              f"最大平均累计误差={cum_err.max():.4e},  均值平均累计误差={cum_err.mean():.4e}")

    # ============================================================
    # 6. 坐标轴与标注
    # ============================================================
    ax.set_xlabel("Time (fs)", fontsize=16)
    ax.set_ylabel("Average Cumulative Error", fontsize=16)
    ax.set_title(
        "Average Cumulative Error of FMO Model at 300K \n"
        "Reference data: χ'=256",
        fontsize=16
    )
    ax.set_xlim(left=0,right=1000)
    ax.set_ylim(bottom=0)
    ax.tick_params(labelsize=13)
    ax.legend(fontsize=13, framealpha=0.85, edgecolor="gray")
    ax.grid(True, alpha=0.35)

    plt.tight_layout()
    # plt.savefig("FMO_avg_cumulative_error_vs_256bd.png", dpi=150)
    # print("\n✅ 已保存: FMO_avg_cumulative_error_vs_256bd.png")
    plt.show()


plot_fmo_error()
# Out:
# Benchmark : singleset_256bd.xlsx
#   行数=252, 列数=7, dt=3.8702 fs
#   时间范围: 0 ~ 971.4 fs
#
#   [已绘制] singleset  ($\chi'=16$)
#     时间范围: 0 ~ 971.4 fs,  最大平均累计误差=2.9028e-02,  均值平均累计误差=1.2243e-02
#   [已绘制] singleset  ($\chi'=64$)
#     时间范围: 0 ~ 971.4 fs,  最大平均累计误差=1.9888e-02,  均值平均累计误差=7.9960e-03
#   [已绘制] singleset_strictkrylov  ($\chi'=16$)
#     时间范围: 0 ~ 971.4 fs,  最大平均累计误差=2.8126e-02,  均值平均累计误差=1.1430e-02
#   [已绘制] singleset_strictkrylov  ($\chi'=64$)
#     时间范围: 0 ~ 971.4 fs,  最大平均累计误差=1.0375e-02,  均值平均累计误差=3.8625e-03
#   [跳过] 文件不存在: ./singleset_128bd.xlsx
